# %% [markdown]
# # Imports

# %%
from ..utils import visualization as vis

# %%
# math
import numpy as np
import torch

# Image processing
# import cv2
import PIL 

# visualization
import matplotlib.pyplot as plt
import seaborn as sns
import moviepy.editor as mpy
from moviepy.video.io.bindings import mplfig_to_npimage
from moviepy.video.VideoClip import DataVideoClip

# directory
import os
from glob import glob

# notebook
from tqdm.auto import tqdm
from IPython.display import clear_output

# %% [markdown]
# # basic matplotlib video

# %%
x = np.linspace(0, 5, 11)

fig = plt.figure(facecolor="white")
base_plot = plt.plot(x, x, 'o-')

def data_to_frame(t):
    y_t = x ** t
    base_plot[0].set_ydata(y_t)
    base_plot[0].set_label(f'pow: {t:.2f}')
    plt.legend()
    plt.ylim(-1, max(y_t))

    return mplfig_to_npimage(fig)

timesteps = np.linspace(1, 5, 30)
clip = DataVideoClip(timesteps, data_to_frame, fps=15)

clip.write_videofile(os.path.join("outputs","graph_power.mp4"))

clear_output()
_ = plt.clf()

mpy.ipython_display(os.path.join("outputs","graph_power.mp4"))
# Out:
# <div align=middle><video src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %%
POSE_CONNECTIONS = [(15, 21), (16, 20), (18, 20), ( 3,  7), (14, 16), (23, 25), (28, 30), (11, 23), (27, 31), ( 6,  8), (15, 17), (24, 26), (16, 22), ( 4,  5), ( 5,  6), (29, 31), (12, 24), (23, 24), ( 0,  1), ( 9, 10), ( 1,  2), ( 0,  4), (11, 13), (30, 32), (28, 32), (15, 19), (16, 18), (25, 27), (26, 28), (12, 14), (17, 19), ( 2,  3), (11, 12), (27, 29), (13, 15)]
HAND_CONNECTIONS = [( 3,  4), ( 0,  5), (17, 18), ( 0, 17), (13, 14), (13, 17), (18, 19), ( 5,  6), ( 5,  9), (14, 15), ( 0,  1), ( 9, 10), ( 1,  2), ( 9, 13), (10, 11), (19, 20), ( 6,  7), (15, 16), ( 2,  3), (11, 12), ( 7,  8)]

# %%
l1
# Out:
# 35

# %%
sorted(POSE_CONNECTIONS)
# Out:
# [(0, 1),
#  (0, 4),
#  (1, 2),
#  (2, 3),
#  (3, 7),
#  (4, 5),
#  (5, 6),
#  (6, 8),
#  (9, 10),
#  (11, 12),
#  (11, 13),
#  (11, 23),
#  (12, 14),
#  (12, 24),
#  (13, 15),
#  (14, 16),
#  (15, 17),
#  (15, 19),
#  (15, 21),
#  (16, 18),
#  (16, 20),
#  (16, 22),
#  (17, 19),
#  (18, 20),
#  (23, 24),
#  (23, 25),
#  (24, 26),
#  (25, 27),
#  (26, 28),
#  (27, 29),
#  (27, 31),
#  (28, 30),
#  (28, 32),
#  (29, 31),
#  (30, 32)]

# %%
[(l1+s,l1+e) for s,e in sorted(HAND_CONNECTIONS)]
# Out:
# [(33, 34),
#  (33, 38),
#  (33, 50),
#  (34, 35),
#  (35, 36),
#  (36, 37),
#  (38, 39),
#  (38, 42),
#  (39, 40),
#  (40, 41),
#  (42, 43),
#  (42, 46),
#  (43, 44),
#  (44, 45),
#  (46, 47),
#  (46, 50),
#  (47, 48),
#  (48, 49),
#  (50, 51),
#  (51, 52),
#  (52, 53)]

# %%
[(l2+s,l2+e) for s,e in sorted(HAND_CONNECTIONS)]
# Out:
# [(54, 55),
#  (54, 59),
#  (54, 71),
#  (55, 56),
#  (56, 57),
#  (57, 58),
#  (59, 60),
#  (59, 63),
#  (60, 61),
#  (61, 62),
#  (63, 64),
#  (63, 67),
#  (64, 65),
#  (65, 66),
#  (67, 68),
#  (67, 71),
#  (68, 69),
#  (69, 70),
#  (71, 72),
#  (72, 73),
#  (73, 74)]

# %%
l1 = max([item for tup in POSE_CONNECTIONS for item in tup])+1
l2 = l1+max([item for tup in HAND_CONNECTIONS for item in tup])+1

# %%
# Out:
# [(0, 1),
#  (0, 4),
#  (1, 2),
#  (2, 3),
#  (3, 7),
#  (4, 5),
#  (5, 6),
#  (6, 8),
#  (9, 10),
#  (11, 12),
#  (11, 13),
#  (11, 23),
#  (12, 14),
#  (12, 24),
#  (13, 15),
#  (14, 16),
#  (15, 17),
#  (15, 19),
#  (15, 21),
#  (16, 18),
#  (16, 20),
#  (16, 22),
#  (17, 19),
#  (18, 20),
#  (23, 24),
#  (23, 25),
#  (24, 26),
#  (25, 27),
#  (26, 28),
#  (27, 29),
#  (27, 31),
#  (28, 30),
#  (28, 32),
#  (29, 31),
#  (30, 32),
#  (33, 34),
#  (33, 38),
#  (33, 50),
#  (34, 35),
#  (35, 36),
#  (36, 37),
#  (38, 39),
#  (38, 42),
#  (39, 40),
#  (40, 41),
#  (42, 43),
#  (42, 46),
#  (43, 44),
#  (44, 45),
#  (46, 47),
#  (46, 50),
#  (47, 48),
#  (48, 49),
#  (50, 51),
#  (51, 52),
#  (52, 53),
#  (54, 55),
#  (54, 59),
#  (54, 71),
#  (55, 56),
#  (56, 57),
#  (57, 58),
#  (59, 60),
#  (59, 63),
#  (60, 61),
#  (61, 62),
#  (63, 64),
#  (63, 67),
#  (64, 65),
#  (65, 66),
#  (67, 68),
#  (67, 71),
#  (68, 69),
#  (69, 70),
#  (71, 72),
#  (72, 73),
#  (73, 74)]
